# %% [markdown]
# <a href="https://colab.research.google.com/github/komarojugnanavi79-rgb/IIY-IV-sem-IRS/blob/main/TF-IDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

corpus = [
    'data science is one of the most important fields of science',
    'this is the one of the best data science courses',
    'data scientists analyze data'
]

# Build vocabulary
words_set = set()
for doc in corpus:
    words = doc.split()
    words_set = words_set.union(set(words))

print('Number of words in the corpus:', len(words_set))
print('The words in the corpus:\n', words_set)

n_docs = len(corpus)
n_words_set = len(words_set)

# Term Frequency (TF)
df_tf = pd.DataFrame(np.zeros((n_docs, n_words_set)), columns=list(words_set))
for i in range(n_docs):
    words = corpus[i].split()
    for w in words:
        df_tf.loc[i, w] += 1 / len(words)

# Inverse Document Frequency (IDF)
idf = {}
print("IDF of:")
for w in words_set:
    k = sum(1 for doc in corpus if w in doc.split())
    idf[w] = np.log10(n_docs / k)
    print(f'{w:>15}: {idf[w]:>10.4f}')

# TF–IDF
df_tf_idf = df_tf.copy()
for w in words_set:
    df_tf_idf[w] = df_tf[w] * idf[w]

print("\nTF–IDF Matrix:")
print(df_tf_idf.round(6))
# Out:
# Number of words in the corpus: 14
# The words in the corpus:
#  {'this', 'scientists', 'the', 'most', 'fields', 'science', 'best', 'data', 'of', 'is', 'one', 'courses', 'important', 'analyze'}
# IDF of:
#            this:     0.4771
#      scientists:     0.4771
#             the:     0.1761
#            most:     0.4771
#          fields:     0.4771
#         science:     0.1761
#            best:     0.4771
#            data:     0.0000
#              of:     0.1761
#              is:     0.1761
#             one:     0.1761
#         courses:     0.4771
#       important:     0.4771
#         analyze:     0.4771
#
# TF–IDF Matrix:
#        this  scientists       the      most    fields   science      best  \
# 0  0.000000     0.00000  0.016008  0.043375  0.043375  0.032017  0.000000
# 1  0.047712     0.00000  0.035218  0.000000  0.000000  0.017609  0.047712
# 2  0.000000     0.11928  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...
