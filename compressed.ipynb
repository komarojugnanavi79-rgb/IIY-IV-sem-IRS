# %% [markdown]
# <a href="https://colab.research.google.com/github/komarojugnanavi79-rgb/IIY-IV-sem-IRS/blob/main/compressed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def compress(text):
   compressed_string = ""
   if not text:
       return compressed_string

   count = 1
   for i in range(1, len(text)):
     if text[i] == text[i-1]:
         count += 1
     else:
         compressed_string += text[i-1] + str(count)
         count = 1
   compressed_string += text[-1] + str(count)
   return compressed_string

with open("input.txt", "w") as f:
  f.write("AAGGTTT66")
with open("input.txt", "r") as f:
  data = f.read()

compressed_data = compress(data)

with open("compressed.txt", "w") as f:
  f.write(compressed_data)
print("Original:", data)
print("Compressed:", compressed_data)
# Out:
# Original: AAGGTTT66
# Compressed: A2G2T362
