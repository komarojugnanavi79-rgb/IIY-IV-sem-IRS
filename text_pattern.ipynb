# %% [markdown]
# <a href="https://colab.research.google.com/github/komarojugnanavi79-rgb/IIY-IV-sem-IRS/blob/main/text_pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def locate(sub, main):
  size_main = len(main)
  size_sub = len(sub)

  print("Given String :", main)
  print("Search String:", sub)
  print("----------------------")

  found_any = False
  index = 0
  while index <= size_main - size_sub:
    k = 0
    match_found_at_current_index = True
    while k < size_sub:
      if main[index + k] != sub[k]:
        match_found_at_current_index = False
        break
      k = k + 1

    if match_found_at_current_index:
      print("Substring exists at position", index)
      found_any = True

    index = index + 1
  if not found_any:
    print("Substring not found in given string")

full_text = "AABAACAADAABAABA"
search_text = "AABA"

locate(search_text, full_text)
# Out:
# Given String : AABAACAADAABAABA
# Search String: AABA
# ----------------------
# Substring exists at position 0
# Substring exists at position 9
# Substring exists at position 12
